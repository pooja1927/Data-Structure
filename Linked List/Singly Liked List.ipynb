# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.ref = None

class LinkedList():
  def __init__(self):
    self.head = None

  ## linked list traversal
  def printLL(self):
    if self.head is None:
      print('Linked List is Empty')
    else:
      n = self.head 
      while n is not None:
        print(n.data, "--->", end=" ")
        n = n.ref

LL = LinkedList()
LL.printLL()
# Out:
# Linked List is Empty

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.ref = None

class LinkedList():
  def __init__(self):
    self.head = None

  ## linked list traversal
  def printLL(self):
    if self.head is None:
      print('Linked List is Empty')
    else:
      n = self.head 
      while n is not None:
        print(n.data, "--->", end=" ")
        n = n.ref
  ##Add element at the beginning
  def addBegin(self, data):
    new_node = Node(data)
    new_node.ref = self.head 
    self.head = new_node
LL = LinkedList()
LL.addBegin(30)
LL.addBegin(20)
LL.addBegin(10)
LL.addBegin(40)
LL.printLL()
# Out:
# 40 ---> 10 ---> 20 ---> 30 --->

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.ref = None

class LinkedList():
  def __init__(self):
    self.head = None

  ## linked list traversal
  def printLL(self):
    if self.head is None:
      print('Linked List is Empty')
    else:
      n = self.head 
      while n is not None:
        print(n.data, "--->", end=" ")
        n = n.ref

  ##Add element at the beginning
  def addBegin(self, data):
    new_node = Node(data)
    new_node.ref = self.head 
    self.head = new_node

  ##Add element at the end
  def addEnd(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
    else:
      n = self.head 
      while n.ref is not None:
        n = n.ref 
      n.ref = new_node

LL = LinkedList()
LL.addBegin(30)
LL.addBegin(20)
LL.addBegin(10)
LL.addEnd(40)
LL.printLL()
# Out:
# 10 ---> 20 ---> 30 ---> 40 --->

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.ref = None

class LinkedList():
  def __init__(self):
    self.head = None

  ## linked list traversal
  def printLL(self):
    if self.head is None:
      print('Linked List is Empty')
    else:
      n = self.head 
      while n is not None:
        print(n.data, "--->", end=" ")
        n = n.ref

  ##Add element at the beginning
  def addBegin(self, data):
    new_node = Node(data)
    new_node.ref = self.head 
    self.head = new_node

  ##Add element at the end
  def addEnd(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
    else:
      n = self.head 
      while n.ref is not None:
        n = n.ref 
      n.ref = new_node
  
  ##Add element after perticular element
  def afterNode(self, data, x):
    new_node = Node(data) 
    if self.head is None:
      print('Linked List is Empty')   
    else:
      n = self.head
      while n.data is not x:
        n = n.ref
      temp = n.ref
      n.ref = new_node
      new_node.ref = temp

LL = LinkedList()
LL.addBegin(30)
LL.addBegin(20)
LL.addBegin(10)
LL.addEnd(40)
LL.printLL()
print()
LL.afterNode(50, 10)
LL.printLL()
# Out:
# 10 ---> 20 ---> 30 ---> 40 --->
# 10 ---> 50 ---> 20 ---> 30 ---> 40 --->

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.ref = None

class LinkedList():
  def __init__(self):
    self.head = None

  ## linked list traversal
  def printLL(self):
    if self.head is None:
      print('Linked List is Empty')
    else:
      n = self.head 
      while n is not None:
        print(n.data, "--->", end=" ")
        n = n.ref

  ##Add element at the beginning
  def addBegin(self, data):
    new_node = Node(data)
    new_node.ref = self.head 
    self.head = new_node

  ##Add element at the end
  def addEnd(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
    else:
      n = self.head 
      while n.ref is not None:
        n = n.ref 
      n.ref = new_node

  ##Add element after perticular element
  def afterNode(self, data, x):
    new_node = Node(data) 
    if self.head is None:
      self.head = new_node   
    else:
      n = self.head
      while n.data is not x:
        n = n.ref
      temp = n.ref
      n.ref = new_node
      new_node.ref = temp
  
  ##Add element before perticular element
  def beforeNode(self, data, x):
    new_node = Node(data) 
    if self.head is None:
      self.head = new_node  
    else:
      n = self.head
      while n.ref.data is not x:
        n = n.ref
      temp = n.ref
      n.ref = new_node
      new_node.ref = temp

LL = LinkedList()
LL.addBegin(30)
LL.addBegin(20)
LL.addBegin(10)
LL.addEnd(40)
LL.printLL()
print()
LL.afterNode(50, 10)
LL.printLL()
print()
LL.beforeNode(87, 40)
LL.printLL()
# Out:
# 10 ---> 20 ---> 30 ---> 40 --->
# 10 ---> 50 ---> 20 ---> 30 ---> 40 --->
# 10 ---> 50 ---> 20 ---> 30 ---> 87 ---> 40 --->

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.ref = None

class LinkedList():
  def __init__(self):
    self.head = None

  ## linked list traversal
  def printLL(self):
    if self.head is None:
      print('Linked List is Empty')
    else:
      n = self.head 
      while n is not None:
        print(n.data, "--->", end=" ")
        n = n.ref

  ##Add element at the beginning
  def addBegin(self, data):
    new_node = Node(data)
    new_node.ref = self.head 
    self.head = new_node

  ##Add element at the end
  def addEnd(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
    else:
      n = self.head 
      while n.ref is not None:
        n = n.ref 
      n.ref = new_node

  ##Add element after perticular element
  def afterNode(self, data, x):
    new_node = Node(data) 
    if self.head is None:
      self.head = new_node   
    else:
      n = self.head
      while n.data is not x:
        n = n.ref
      temp = n.ref
      n.ref = new_node
      new_node.ref = temp
  
  ##Add element before perticular element
  def beforeNode(self, data, x):
    new_node = Node(data) 
    if self.head is None:
      self.head = new_node  
    else:
      n = self.head
      while n.ref.data is not x:
        n = n.ref
      temp = n.ref
      n.ref = new_node
      new_node.ref = temp
  
  ## Delete Node from beginning
  def deleteBegin(self):
    if self.head is None:
      print('Linked list is empty')
    else:
      n = self.head 
      self.head = n.ref

LL = LinkedList()
LL.addBegin(30)
LL.addBegin(20)
LL.addBegin(10)
LL.addEnd(40)
LL.printLL()
print()
LL.afterNode(50, 10)
LL.printLL()
print()
LL.beforeNode(87, 40)
LL.printLL()
print()
LL.deleteBegin()
LL.printLL()
# Out:
# 10 ---> 20 ---> 30 ---> 40 --->
# 10 ---> 50 ---> 20 ---> 30 ---> 40 --->
# 10 ---> 50 ---> 20 ---> 30 ---> 87 ---> 40 --->
# 50 ---> 20 ---> 30 ---> 87 ---> 40 --->

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.ref = None

class LinkedList():
  def __init__(self):
    self.head = None

  ## linked list traversal
  def printLL(self):
    if self.head is None:
      print('Linked List is Empty')
    else:
      n = self.head 
      while n is not None:
        print(n.data, "--->", end=" ")
        n = n.ref

  ##Add element at the beginning
  def addBegin(self, data):
    new_node = Node(data)
    new_node.ref = self.head 
    self.head = new_node

  ##Add element at the end
  def addEnd(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
    else:
      n = self.head 
      while n.ref is not None:
        n = n.ref 
      n.ref = new_node

  ##Add element after perticular element
  def afterNode(self, data, x):
    new_node = Node(data) 
    if self.head is None:
      self.head = new_node   
    else:
      n = self.head
      while n.data is not x:
        n = n.ref
      temp = n.ref
      n.ref = new_node
      new_node.ref = temp
  
  ##Add element before perticular element
  def beforeNode(self, data, x):
    new_node = Node(data) 
    if self.head is None:
      self.head = new_node  
    else:
      n = self.head
      while n.ref.data is not x:
        n = n.ref
      temp = n.ref
      n.ref = new_node
      new_node.ref = temp
  
  ## Delete Node from beginning
  def deleteBegin(self):
    if self.head is None:
      print('Linked list is empty')
    else:
      n = self.head 
      self.head = n.ref

  ## Delete node from end
  def deleteEnd(self):
    if self.head is None:
      print('Linked list is empty')
    else:
      n = self.head 
      while n.ref.ref is not None:
        n = n.ref
      n.ref = None

LL = LinkedList()
LL.addBegin(30)
LL.addBegin(20)
LL.addBegin(10)
LL.addEnd(40)
LL.printLL()
print()
LL.afterNode(50, 10)
LL.printLL()
print()
LL.beforeNode(87, 40)
LL.printLL()
print()
LL.deleteBegin()
LL.printLL()
print()
LL.deleteEnd()
LL.printLL()
# Out:
# 10 ---> 20 ---> 30 ---> 40 --->
# 10 ---> 50 ---> 20 ---> 30 ---> 40 --->
# 10 ---> 50 ---> 20 ---> 30 ---> 87 ---> 40 --->
# 50 ---> 20 ---> 30 ---> 87 ---> 40 --->
# 50 ---> 20 ---> 30 ---> 87 --->

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.ref = None

class LinkedList():
  def __init__(self):
    self.head = None

  ## linked list traversal
  def printLL(self):
    if self.head is None:
      print('Linked List is Empty')
    else:
      n = self.head 
      while n is not None:
        print(n.data, "--->", end=" ")
        n = n.ref

  ##Add element at the beginning
  def addBegin(self, data):
    new_node = Node(data)
    new_node.ref = self.head 
    self.head = new_node

  ##Add element at the end
  def addEnd(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
    else:
      n = self.head 
      while n.ref is not None:
        n = n.ref 
      n.ref = new_node

  ##Add element after perticular element
  def afterNode(self, data, x):
    new_node = Node(data) 
    if self.head is None:
      self.head = new_node   
    else:
      n = self.head
      while n.data is not x:
        n = n.ref
      temp = n.ref
      n.ref = new_node
      new_node.ref = temp
  
  ##Add element before perticular element
  def beforeNode(self, data, x):
    new_node = Node(data) 
    if self.head is None:
      self.head = new_node  
    else:
      n = self.head
      while n.ref.data is not x:
        n = n.ref
      temp = n.ref
      n.ref = new_node
      new_node.ref = temp
  
  ## Delete Node from beginning
  def deleteBegin(self):
    if self.head is None:
      print('Linked list is empty')
    else:
      n = self.head 
      self.head = n.ref

  ## Delete node from end
  def deleteEnd(self):
    if self.head is None:
      print('Linked list is empty')
    else:
      n = self.head 
      while n.ref.ref is not None:
        n = n.ref
      n.ref = None

  ## Delete node from inbetween
  def deleteBetween(self, x):
    if self.head is None:
      print('Linked list is empty')
    else:
      n = self.head 
      while n.ref.data is not x:
        n = n.ref
      n.ref = n.ref.ref

LL = LinkedList()
LL.addBegin(30)
LL.addBegin(20)
LL.addBegin(10)
LL.addEnd(40)
LL.printLL()
print()
LL.afterNode(50, 10)
LL.printLL()
print()
LL.beforeNode(87, 40)
LL.printLL()
print()
LL.deleteBegin()
LL.printLL()
print()
LL.deleteEnd()
LL.printLL()
print()
LL.deleteBetween(30)
LL.printLL()
# Out:
# 10 ---> 20 ---> 30 ---> 40 --->
# 10 ---> 50 ---> 20 ---> 30 ---> 40 --->
# 10 ---> 50 ---> 20 ---> 30 ---> 87 ---> 40 --->
# 50 ---> 20 ---> 30 ---> 87 ---> 40 --->
# 50 ---> 20 ---> 30 ---> 87 --->
# 50 ---> 20 ---> 87 --->
